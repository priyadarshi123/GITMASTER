# %%
from ib_async import *
position=[Position(account='DU2878459', contract=Stock(conId=604409899, symbol='SDIV', exchange='ARCA', currency='USD', localSymbol='SDIV', tradingClass='SDIV'), position=3.3333, avgCost=35.8803588)]
yoyo = util.df[position]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 from ib_async import *
#       2 position=[Position(account='DU2878459', contract=Stock(conId=604409899, symbol='SDIV', exchange='ARCA', currency='USD', localSymbol='SDIV', tradingClass='SDIV'), position=3.3333, avgCost=35.8803588)]
# ----> 3 yoyo = util.df[position]
#
# TypeError: 'function' object is not subscriptable

# %%
yo['account']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 yo['account']
#
# TypeError: list indices must be integers or slices, not str
